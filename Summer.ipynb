# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
import pandas as pd
dataFile = pd.read_csv("summer.csv")
len(dataFile['City'].unique())
# Out:
# 22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
sports = dataFile['Sport'].unique()
sport_medal_count = []
for sport in sports:
    x = dataFile[dataFile['Sport'] == sport]
    sport_medal_count.append([sport,len(x[x['Medal'] == 'Gold'])])
y = pd.DataFrame(sport_medal_count, columns=['Sport','MedalCount']).sort_values(by='MedalCount',ascending=False).head().plot(x='Sport', y='MedalCount', kind='bar')    
for z in y.patches:
    y.annotate(str(z.get_height()), (z.get_x() * 1.005, z.get_height() * 1.005))

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
sports = dataFile['Sport'].unique()
sport_medal_count = []
for sport in sports:
    x = dataFile[dataFile['Sport'] == sport]
    sport_medal_count.append([sport,len(x)])
y = pd.DataFrame(sport_medal_count, columns=['Sport','MedalCount']).sort_values(by='MedalCount',ascending=False).head().plot(x='Sport', y='MedalCount', kind='bar')
for z in y.patches:
    y.annotate(str(z.get_height()), (z.get_x() * 1.005, z.get_height() * 1.005))

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
athletes = dataFile['Athlete'].unique()
medal_count = []
for athlete in athletes:
    x = dataFile[dataFile['Athlete'] == athlete]
    medal_count.append([athlete,len(x)])
y = pd.DataFrame(medal_count, columns=['Athlete','MedalCount']).sort_values(by='MedalCount',ascending=False).head().plot(x='Athlete', y='MedalCount', kind='bar')
for z in y.patches:
    y.annotate(str(z.get_height()), (z.get_x() * 1.005, z.get_height() * 1.005))

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
athletes = dataFile['Athlete'].unique()
medal_count = []
for athlete in athletes:
    x = dataFile[dataFile['Athlete'] == athlete]
    medal_count.append([athlete,len(x[x['Medal'] == 'Gold'])])
y = pd.DataFrame(medal_count, columns=['Athlete','MedalCount']).sort_values(by='MedalCount',ascending=False).head().plot(x='Athlete', y='MedalCount', kind='bar')    
for z in y.patches:
    y.annotate(str(z.get_height()), (z.get_x() * 1.005, z.get_height() * 1.005))

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
indianMedals = dataFile[dataFile['Country'] == 'IND']
indianMedalsYears = indianMedals[indianMedals['Medal'] == 'Gold']
years = []
for year in indianMedalsYears['Year']:
    years.append(year)
print(min(years))
# Out:
# 1928

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
events = dataFile['Event'].unique()
eventPlayers = []
for event in events:
        x = dataFile[dataFile['Event'] == event]
        eventPlayers.append([event,len(x)])
y = pd.DataFrame(eventPlayers, columns=['Event','PlayerCount']).sort_values(by='PlayerCount',ascending=False).head().plot(x='Event', y='PlayerCount', kind='bar') 
for z in y.patches:
    y.annotate(str(z.get_height()), (z.get_x() * 1.005, z.get_height() * 1.005))

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
femaledataFile = dataFile[dataFile['Gender'] == 'Women']
sports = femaledataFile['Sport'].unique()
sport_medal_count = []
for sport in sports:
    x = femaledataFile[femaledataFile['Sport'] == sport]
    sport_medal_count.append([sport,len(x[x['Medal'] == 'Gold'])])
y = pd.DataFrame(sport_medal_count, columns=['Sport','MedalCount']).sort_values(by='MedalCount',ascending=False).head().plot(x='Sport', y='MedalCount', kind='bar')   
for z in y.patches:
    y.annotate(str(z.get_height()), (z.get_x() * 1.005, z.get_height() * 1.005))
